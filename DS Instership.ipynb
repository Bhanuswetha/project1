# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline
sns.set()

# %%
df = pd.read_csv('C:/Users/91949/Downloads/voice.csv')
df
# Out:
#       meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0     0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1     0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2     0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3     0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4     0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
# ...        ...       ...       ...       ...       ...       ...        ...
# 3163  0.131884  0.084734  0.153707  0.049285  0.201144  0.151859   1.762129
# 3164  0.116221  0.089221  0.076758  0.042718  0.204911  0.162193   0.693730
# 3165  0.142056  0.095798  0.183731  0.033424  0.224360  0.190936   1.876502
# 3166  0.143659  0.090628  0.184976  0.043508  0.219943  0.176435   1.591065
# 3167  0.165509  0.092884  0.183044  0.070072  0.250827  0.180756   1.705029
#
# ...

# %%
df.shape
# Out:
# (3168, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3168 entries, 0 to 3167
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   meanfreq  3168 non-null   float64
#  1   sd        3168 non-null   float64
#  2   median    3168 non-null   float64
#  3   Q25       3168 non-null   float64
#  4   Q75       3168 non-null   float64
#  5   IQR       3168 non-null   float64
#  6   skew      3168 non-null   float64
#  7   kurt      3168 non-null   float64
#  8   sp.ent    3168 non-null   float64
#  9   sfm       3168 non-null   float64
#  10  mode      3168 non-null   float64
#  11  centroid  3168 non-null   float64
#  12  meanfun   3168 non-null   float64
#  13  minfun    3168 non-null   float64
#  14  maxfun    3168 non-null   float64
#  15  meandom   3168 non-null   float64
#  16  mindom    3168 non-null   float64
#  17  maxdom    3168 non-null   float64
#  18  dfrange   3168 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# meanfreq    0
# sd          0
# median      0
# Q25         0
# Q75         0
# IQR         0
# skew        0
# kurt        0
# sp.ent      0
# sfm         0
# mode        0
# centroid    0
# meanfun     0
# minfun      0
# maxfun      0
# meandom     0
# mindom      0
# maxdom      0
# dfrange     0
# modindx     0
# label       0
# dtype: int64

# %%
df.describe(include = object)
# Out:
#        label
# count   3168
# unique     2
# top     male
# freq    1584

# %%
df1 = df.drop("meanfreq",axis = 1)
df1
# Out:
#             sd    median       Q25       Q75       IQR       skew  \
# 0     0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1     0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2     0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3     0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4     0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
# ...        ...       ...       ...       ...       ...        ...
# 3163  0.084734  0.153707  0.049285  0.201144  0.151859   1.762129
# 3164  0.089221  0.076758  0.042718  0.204911  0.162193   0.693730
# 3165  0.095798  0.183731  0.033424  0.224360  0.190936   1.876502
# 3166  0.090628  0.184976  0.043508  0.219943  0.176435   1.591065
# 3167  0.092884  0.183044  0.070072  0.250827  0.180756   1.705029
#
#              kurt    sp.ent       sfm      mode  centroid   meanfun    minfun  \
# 0      274.402905  0.893369  0.491918  0.000000  0.059781  0.084279  0.015702
# ...

# %%
df1 = df1.drop("sd",axis = 1)
df1
# Out:
#         median       Q25       Q75       IQR       skew         kurt  \
# 0     0.032027  0.015071  0.090193  0.075122  12.863462   274.402905
# 1     0.040229  0.019414  0.092666  0.073252  22.423285   634.613855
# 2     0.036718  0.008701  0.131908  0.123207  30.757155  1024.927705
# 3     0.158011  0.096582  0.207955  0.111374   1.232831     4.177296
# 4     0.124656  0.078720  0.206045  0.127325   1.101174     4.333713
# ...        ...       ...       ...       ...        ...          ...
# 3163  0.153707  0.049285  0.201144  0.151859   1.762129     6.630383
# 3164  0.076758  0.042718  0.204911  0.162193   0.693730     2.503954
# 3165  0.183731  0.033424  0.224360  0.190936   1.876502     6.604509
# 3166  0.184976  0.043508  0.219943  0.176435   1.591065     5.388298
# 3167  0.183044  0.070072  0.250827  0.180756   1.705029     5.769115
#
#         sp.ent       sfm      mode  centroid   meanfun    minfun    maxfun  \
# ...

# %%
df1 = df1.drop("Q25",axis = 1)
df1
# Out:
#         median       Q75       IQR       skew         kurt    sp.ent  \
# 0     0.032027  0.090193  0.075122  12.863462   274.402905  0.893369
# 1     0.040229  0.092666  0.073252  22.423285   634.613855  0.892193
# 2     0.036718  0.131908  0.123207  30.757155  1024.927705  0.846389
# 3     0.158011  0.207955  0.111374   1.232831     4.177296  0.963322
# 4     0.124656  0.206045  0.127325   1.101174     4.333713  0.971955
# ...        ...       ...       ...        ...          ...       ...
# 3163  0.153707  0.201144  0.151859   1.762129     6.630383  0.962934
# 3164  0.076758  0.204911  0.162193   0.693730     2.503954  0.960716
# 3165  0.183731  0.224360  0.190936   1.876502     6.604509  0.946854
# 3166  0.184976  0.219943  0.176435   1.591065     5.388298  0.950436
# 3167  0.183044  0.250827  0.180756   1.705029     5.769115  0.938829
#
#            sfm      mode  centroid   meanfun    minfun    maxfun   meandom  \
# ...

# %%
df1 = df1.drop("Q75",axis = 1)
df1
# Out:
#         median       IQR       skew         kurt    sp.ent       sfm  \
# 0     0.032027  0.075122  12.863462   274.402905  0.893369  0.491918
# 1     0.040229  0.073252  22.423285   634.613855  0.892193  0.513724
# 2     0.036718  0.123207  30.757155  1024.927705  0.846389  0.478905
# 3     0.158011  0.111374   1.232831     4.177296  0.963322  0.727232
# 4     0.124656  0.127325   1.101174     4.333713  0.971955  0.783568
# ...        ...       ...        ...          ...       ...       ...
# 3163  0.153707  0.151859   1.762129     6.630383  0.962934  0.763182
# 3164  0.076758  0.162193   0.693730     2.503954  0.960716  0.709570
# 3165  0.183731  0.190936   1.876502     6.604509  0.946854  0.654196
# 3166  0.184976  0.176435   1.591065     5.388298  0.950436  0.675470
# 3167  0.183044  0.180756   1.705029     5.769115  0.938829  0.601529
#
#           mode  centroid   meanfun    minfun    maxfun   meandom    mindom  \
# ...

# %%
df1 = df1.drop("IQR",axis = 1)
df1
# Out:
#         median       skew         kurt    sp.ent       sfm      mode  \
# 0     0.032027  12.863462   274.402905  0.893369  0.491918  0.000000
# 1     0.040229  22.423285   634.613855  0.892193  0.513724  0.000000
# 2     0.036718  30.757155  1024.927705  0.846389  0.478905  0.000000
# 3     0.158011   1.232831     4.177296  0.963322  0.727232  0.083878
# 4     0.124656   1.101174     4.333713  0.971955  0.783568  0.104261
# ...        ...        ...          ...       ...       ...       ...
# 3163  0.153707   1.762129     6.630383  0.962934  0.763182  0.200836
# 3164  0.076758   0.693730     2.503954  0.960716  0.709570  0.013683
# 3165  0.183731   1.876502     6.604509  0.946854  0.654196  0.008006
# 3166  0.184976   1.591065     5.388298  0.950436  0.675470  0.212202
# 3167  0.183044   1.705029     5.769115  0.938829  0.601529  0.267702
#
#       centroid   meanfun    minfun    maxfun   meandom    mindom    maxdom  \
# ...

# %%
df1 = df1.drop("median",axis = 1)
df1
# Out:
#            skew         kurt    sp.ent       sfm      mode  centroid  \
# 0     12.863462   274.402905  0.893369  0.491918  0.000000  0.059781
# 1     22.423285   634.613855  0.892193  0.513724  0.000000  0.066009
# 2     30.757155  1024.927705  0.846389  0.478905  0.000000  0.077316
# 3      1.232831     4.177296  0.963322  0.727232  0.083878  0.151228
# 4      1.101174     4.333713  0.971955  0.783568  0.104261  0.135120
# ...         ...          ...       ...       ...       ...       ...
# 3163   1.762129     6.630383  0.962934  0.763182  0.200836  0.131884
# 3164   0.693730     2.503954  0.960716  0.709570  0.013683  0.116221
# 3165   1.876502     6.604509  0.946854  0.654196  0.008006  0.142056
# 3166   1.591065     5.388298  0.950436  0.675470  0.212202  0.143659
# 3167   1.705029     5.769115  0.938829  0.601529  0.267702  0.165509
#
#        meanfun    minfun    maxfun   meandom    mindom    maxdom   dfrange  \
# ...

# %%
df1 = df1.drop("skew",axis = 1)
df1
# Out:
#              kurt    sp.ent       sfm      mode  centroid   meanfun    minfun  \
# 0      274.402905  0.893369  0.491918  0.000000  0.059781  0.084279  0.015702
# 1      634.613855  0.892193  0.513724  0.000000  0.066009  0.107937  0.015826
# 2     1024.927705  0.846389  0.478905  0.000000  0.077316  0.098706  0.015656
# 3        4.177296  0.963322  0.727232  0.083878  0.151228  0.088965  0.017798
# 4        4.333713  0.971955  0.783568  0.104261  0.135120  0.106398  0.016931
# ...           ...       ...       ...       ...       ...       ...       ...
# 3163     6.630383  0.962934  0.763182  0.200836  0.131884  0.182790  0.083770
# 3164     2.503954  0.960716  0.709570  0.013683  0.116221  0.188980  0.034409
# 3165     6.604509  0.946854  0.654196  0.008006  0.142056  0.209918  0.039506
# 3166     5.388298  0.950436  0.675470  0.212202  0.143659  0.172375  0.034483
# 3167     5.769115  0.938829  0.601529  0.267702  0.165509  0.185607  0.062257
#
# ...

# %%
df1 = df1.drop("kurt",axis = 1)
df1
# Out:
#         sp.ent       sfm      mode  centroid   meanfun    minfun    maxfun  \
# 0     0.893369  0.491918  0.000000  0.059781  0.084279  0.015702  0.275862
# 1     0.892193  0.513724  0.000000  0.066009  0.107937  0.015826  0.250000
# 2     0.846389  0.478905  0.000000  0.077316  0.098706  0.015656  0.271186
# 3     0.963322  0.727232  0.083878  0.151228  0.088965  0.017798  0.250000
# 4     0.971955  0.783568  0.104261  0.135120  0.106398  0.016931  0.266667
# ...        ...       ...       ...       ...       ...       ...       ...
# 3163  0.962934  0.763182  0.200836  0.131884  0.182790  0.083770  0.262295
# 3164  0.960716  0.709570  0.013683  0.116221  0.188980  0.034409  0.275862
# 3165  0.946854  0.654196  0.008006  0.142056  0.209918  0.039506  0.275862
# 3166  0.950436  0.675470  0.212202  0.143659  0.172375  0.034483  0.250000
# 3167  0.938829  0.601529  0.267702  0.165509  0.185607  0.062257  0.271186
#
#        meandom    mindom    maxdom   dfrange   modindx   label
# ...

# %%
df1 = df1.drop("mode",axis = 1)
df1
# Out:
#         sp.ent       sfm  centroid   meanfun    minfun    maxfun   meandom  \
# 0     0.893369  0.491918  0.059781  0.084279  0.015702  0.275862  0.007812
# 1     0.892193  0.513724  0.066009  0.107937  0.015826  0.250000  0.009014
# 2     0.846389  0.478905  0.077316  0.098706  0.015656  0.271186  0.007990
# 3     0.963322  0.727232  0.151228  0.088965  0.017798  0.250000  0.201497
# 4     0.971955  0.783568  0.135120  0.106398  0.016931  0.266667  0.712812
# ...        ...       ...       ...       ...       ...       ...       ...
# 3163  0.962934  0.763182  0.131884  0.182790  0.083770  0.262295  0.832899
# 3164  0.960716  0.709570  0.116221  0.188980  0.034409  0.275862  0.909856
# 3165  0.946854  0.654196  0.142056  0.209918  0.039506  0.275862  0.494271
# 3166  0.950436  0.675470  0.143659  0.172375  0.034483  0.250000  0.791360
# 3167  0.938829  0.601529  0.165509  0.185607  0.062257  0.271186  0.227022
#
#         mindom    maxdom   dfrange   modindx   label
# ...

# %%
df1 = df1.drop("sfm",axis = 1)
df1
# Out:
#         sp.ent  centroid   meanfun    minfun    maxfun   meandom    mindom  \
# 0     0.893369  0.059781  0.084279  0.015702  0.275862  0.007812  0.007812
# 1     0.892193  0.066009  0.107937  0.015826  0.250000  0.009014  0.007812
# 2     0.846389  0.077316  0.098706  0.015656  0.271186  0.007990  0.007812
# 3     0.963322  0.151228  0.088965  0.017798  0.250000  0.201497  0.007812
# 4     0.971955  0.135120  0.106398  0.016931  0.266667  0.712812  0.007812
# ...        ...       ...       ...       ...       ...       ...       ...
# 3163  0.962934  0.131884  0.182790  0.083770  0.262295  0.832899  0.007812
# 3164  0.960716  0.116221  0.188980  0.034409  0.275862  0.909856  0.039062
# 3165  0.946854  0.142056  0.209918  0.039506  0.275862  0.494271  0.007812
# 3166  0.950436  0.143659  0.172375  0.034483  0.250000  0.791360  0.007812
# 3167  0.938829  0.165509  0.185607  0.062257  0.271186  0.227022  0.007812
#
#         maxdom   dfrange   modindx   label
# ...

# %%
df1 = df1.drop("sp.ent",axis = 1)
df1
# Out:
#       centroid   meanfun    minfun    maxfun   meandom    mindom    maxdom  \
# 0     0.059781  0.084279  0.015702  0.275862  0.007812  0.007812  0.007812
# 1     0.066009  0.107937  0.015826  0.250000  0.009014  0.007812  0.054688
# 2     0.077316  0.098706  0.015656  0.271186  0.007990  0.007812  0.015625
# 3     0.151228  0.088965  0.017798  0.250000  0.201497  0.007812  0.562500
# 4     0.135120  0.106398  0.016931  0.266667  0.712812  0.007812  5.484375
# ...        ...       ...       ...       ...       ...       ...       ...
# 3163  0.131884  0.182790  0.083770  0.262295  0.832899  0.007812  4.210938
# 3164  0.116221  0.188980  0.034409  0.275862  0.909856  0.039062  3.679688
# 3165  0.142056  0.209918  0.039506  0.275862  0.494271  0.007812  2.937500
# 3166  0.143659  0.172375  0.034483  0.250000  0.791360  0.007812  3.593750
# 3167  0.165509  0.185607  0.062257  0.271186  0.227022  0.007812  0.554688
#
#        dfrange   modindx   label
# 0     0.000000  0.000000    male
# ...

# %%
df1 = df1.drop("centroid",axis = 1)
df1
# Out:
#        meanfun    minfun    maxfun   meandom    mindom    maxdom   dfrange  \
# 0     0.084279  0.015702  0.275862  0.007812  0.007812  0.007812  0.000000
# 1     0.107937  0.015826  0.250000  0.009014  0.007812  0.054688  0.046875
# 2     0.098706  0.015656  0.271186  0.007990  0.007812  0.015625  0.007812
# 3     0.088965  0.017798  0.250000  0.201497  0.007812  0.562500  0.554688
# 4     0.106398  0.016931  0.266667  0.712812  0.007812  5.484375  5.476562
# ...        ...       ...       ...       ...       ...       ...       ...
# 3163  0.182790  0.083770  0.262295  0.832899  0.007812  4.210938  4.203125
# 3164  0.188980  0.034409  0.275862  0.909856  0.039062  3.679688  3.640625
# 3165  0.209918  0.039506  0.275862  0.494271  0.007812  2.937500  2.929688
# 3166  0.172375  0.034483  0.250000  0.791360  0.007812  3.593750  3.585938
# 3167  0.185607  0.062257  0.271186  0.227022  0.007812  0.554688  0.546875
#
#        modindx   label
# 0     0.000000    male
# ...

# %%
df1 = df1.drop("dfrange",axis = 1)
df1
# Out:
#        meanfun    minfun    maxfun   meandom    mindom    maxdom   modindx  \
# 0     0.084279  0.015702  0.275862  0.007812  0.007812  0.007812  0.000000
# 1     0.107937  0.015826  0.250000  0.009014  0.007812  0.054688  0.052632
# 2     0.098706  0.015656  0.271186  0.007990  0.007812  0.015625  0.046512
# 3     0.088965  0.017798  0.250000  0.201497  0.007812  0.562500  0.247119
# 4     0.106398  0.016931  0.266667  0.712812  0.007812  5.484375  0.208274
# ...        ...       ...       ...       ...       ...       ...       ...
# 3163  0.182790  0.083770  0.262295  0.832899  0.007812  4.210938  0.161929
# 3164  0.188980  0.034409  0.275862  0.909856  0.039062  3.679688  0.277897
# 3165  0.209918  0.039506  0.275862  0.494271  0.007812  2.937500  0.194759
# 3166  0.172375  0.034483  0.250000  0.791360  0.007812  3.593750  0.311002
# 3167  0.185607  0.062257  0.271186  0.227022  0.007812  0.554688  0.350000
#
#        label
# 0       male
# 1       male
# 2       male
# ...

# %%
sns.heatmap(df1.corr(),annot=True,cmap='winter')
# Out:
# <AxesSubplot:>

# %%
x = df1.iloc[:,1:].values
x
# Out:
# array([[0.015701668, 0.275862069, 0.0078125, 0.0078125, 0.0, 'male'],
#        [0.015825915, 0.25, 0.009014423, 0.0078125, 0.052631579, 'male'],
#        [0.015655577, 0.271186441, 0.007990057, 0.0078125, 0.046511628,
#         'male'],
#        ...,
#        [0.039506173, 0.275862069, 0.494270833, 0.0078125, 0.194758621,
#         'female'],
#        [0.034482759, 0.25, 0.791360294, 0.0078125, 0.311002179, 'female'],
#        [0.062256809, 0.271186441, 0.227022059, 0.0078125, 0.35, 'female']],
#       dtype=object)

# %%
y = df1.iloc[:,0].values
y
# Out:
# array([0.08427911, 0.10793655, 0.09870626, ..., 0.20991768, 0.172375  ,
#        0.18560693])

# %%
predict ='label'
df1 = df1[['meanfun','minfun','maxfun','meandom','mindom','modindx','label']]
x = np.array(df1.drop([predict],1))
y = np.array(df1[predict])

from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size = 1/3)
# Out:
# C:\Users\91949\AppData\Local\Temp\ipykernel_4868\2223063673.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x = np.array(df1.drop([predict],1))

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size = 1/3,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state=0)
classifier.fit(xtrain,ytrain)
# Out:
# LogisticRegression(random_state=0)

# %%
ypred = classifier.predict(xtest)
ypred
# Out:
# array(['female', 'male', 'female', ..., 'female', 'male', 'female'],
#       dtype=object)

# %%
ytest
# Out:
# array(['female', 'male', 'female', ..., 'female', 'male', 'female'],
#       dtype=object)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(ytest,ypred)
cm
# Out:
# array([[437,  64],
#        [ 79, 476]], dtype=int64)

# %%
from sklearn import metrics
print('Accuracy:',metrics.accuracy_score(ytest,ypred))
# Out:
# Accuracy: 0.8645833333333334

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=10,criterion='entropy',random_state=0)
clf.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
from sklearn import metrics
print('Accuracy:',metrics.accuracy_score(ytest,ypred))
# Out:
# Accuracy: 0.8645833333333334
