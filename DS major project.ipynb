# %%
# importing 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline
sns.set()

import warnings
warnings.filterwarnings('ignore')

# %%
#Reading the data set
df = pd.read_csv("C:/Users/91949/Downloads/adult.csv")
df
# Out:
#        Age          Workclass  Fnlwgt    Education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.head()
# Out:
#    Age          Workclass  Fnlwgt   Education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df.tail()
# Out:
#        Age      Workclass  Fnlwgt    Education  education_num  \
# 32556   27        Private  257302   Assoc-acdm             12
# 32557   40        Private  154374      HS-grad              9
# 32558   58        Private  151910      HS-grad              9
# 32559   22        Private  201490      HS-grad              9
# 32560   52   Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation relationship    race      sex  \
# 32556   Married-civ-spouse        Tech-support         Wife   White   Female
# 32557   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32558              Widowed        Adm-clerical    Unmarried   White   Female
# 32559        Never-married        Adm-clerical    Own-child   White     Male
# 32560   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        capital_gain  capital_loss  hours_per_week  native_country  income
# ...

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.dtypes
# Out:
# Age                int64
# Workclass         object
# Fnlwgt             int64
# Education         object
# education_num      int64
# marital_status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital_gain       int64
# capital_loss       int64
# hours_per_week     int64
# native_country    object
# income            object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
df.describe().T
# Out:
#                   count           mean            std      min       25%  \
# Age             32561.0      38.581647      13.640433     17.0      28.0
# Fnlwgt          32561.0  189778.366512  105549.977697  12285.0  117827.0
# education_num   32561.0      10.080679       2.572720      1.0       9.0
# capital_gain    32561.0    1077.648844    7385.292085      0.0       0.0
# capital_loss    32561.0      87.303830     402.960219      0.0       0.0
# hours_per_week  32561.0      40.437456      12.347429      1.0      40.0
#
#                      50%       75%        max
# Age                 37.0      48.0       90.0
# Fnlwgt          178356.0  237051.0  1484705.0
# education_num       10.0      12.0       16.0
# capital_gain         0.0       0.0    99999.0
# capital_loss         0.0       0.0     4356.0
# hours_per_week      40.0      45.0       99.0

# %%
df.describe(include = object)
# Out:
#        Workclass Education       marital_status       occupation relationship  \
# count      32561     32561                32561            32561        32561
# unique         9        16                    7               15            6
# top      Private   HS-grad   Married-civ-spouse   Prof-specialty      Husband
# freq       22696     10501                14976             4140        13193
#
#           race    sex  native_country  income
# count    32561  32561           32561   32561
# unique       5      2              42       2
# top      White   Male   United-States   <=50K
# freq     27816  21790           29170   24720

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32561 non-null  int64
#  1   Workclass       32561 non-null  object
#  2   Fnlwgt          32561 non-null  int64
#  3   Education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
(df.isnull().sum()/df.shape[0])*100
#For null values in %
# Out:
# Age               0.0
# Workclass         0.0
# Fnlwgt            0.0
# Education         0.0
# education_num     0.0
# marital_status    0.0
# occupation        0.0
# relationship      0.0
# race              0.0
# sex               0.0
# capital_gain      0.0
# capital_loss      0.0
# hours_per_week    0.0
# native_country    0.0
# income            0.0
# dtype: float64

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'income'],
#       dtype='object')

# %%
# removing workclass from the data set (which is not requied)
df1 = df.drop("Workclass",axis = 1)
df1
# Out:
#        Age  Fnlwgt    Education  education_num       marital_status  \
# 0       39   77516    Bachelors             13        Never-married
# 1       50   83311    Bachelors             13   Married-civ-spouse
# 2       38  215646      HS-grad              9             Divorced
# 3       53  234721         11th              7   Married-civ-spouse
# 4       28  338409    Bachelors             13   Married-civ-spouse
# ...    ...     ...          ...            ...                  ...
# 32556   27  257302   Assoc-acdm             12   Married-civ-spouse
# 32557   40  154374      HS-grad              9   Married-civ-spouse
# 32558   58  151910      HS-grad              9              Widowed
# 32559   22  201490      HS-grad              9        Never-married
# 32560   52  287927      HS-grad              9   Married-civ-spouse
#
#                occupation    relationship    race      sex  capital_gain  \
# 0            Adm-clerical   Not-in-family   White     Male          2174
# ...

# %%
## removing sex from the data set (which is not requied)

df1 = df1.drop("sex",axis = 1)
df1
# Out:
#        Age  Fnlwgt    Education  education_num       marital_status  \
# 0       39   77516    Bachelors             13        Never-married
# 1       50   83311    Bachelors             13   Married-civ-spouse
# 2       38  215646      HS-grad              9             Divorced
# 3       53  234721         11th              7   Married-civ-spouse
# 4       28  338409    Bachelors             13   Married-civ-spouse
# ...    ...     ...          ...            ...                  ...
# 32556   27  257302   Assoc-acdm             12   Married-civ-spouse
# 32557   40  154374      HS-grad              9   Married-civ-spouse
# 32558   58  151910      HS-grad              9              Widowed
# 32559   22  201490      HS-grad              9        Never-married
# 32560   52  287927      HS-grad              9   Married-civ-spouse
#
#                occupation    relationship    race  capital_gain  capital_loss  \
# ...

# %%
## removing race from the data set (which is not requied)

df1 = df1.drop("race",axis = 1)
df1
# Out:
#        Age  Fnlwgt    Education  education_num       marital_status  \
# 0       39   77516    Bachelors             13        Never-married
# 1       50   83311    Bachelors             13   Married-civ-spouse
# 2       38  215646      HS-grad              9             Divorced
# 3       53  234721         11th              7   Married-civ-spouse
# 4       28  338409    Bachelors             13   Married-civ-spouse
# ...    ...     ...          ...            ...                  ...
# 32556   27  257302   Assoc-acdm             12   Married-civ-spouse
# 32557   40  154374      HS-grad              9   Married-civ-spouse
# 32558   58  151910      HS-grad              9              Widowed
# 32559   22  201490      HS-grad              9        Never-married
# 32560   52  287927      HS-grad              9   Married-civ-spouse
#
#                occupation    relationship  capital_gain  capital_loss  \
# 0            Adm-clerical   Not-in-family          2174             0
# ...

# %%
## removing relationship from the data set (which is not requied)

df1 = df1.drop("relationship",axis = 1)
df1
# Out:
#        Age  Fnlwgt    Education  education_num       marital_status  \
# 0       39   77516    Bachelors             13        Never-married
# 1       50   83311    Bachelors             13   Married-civ-spouse
# 2       38  215646      HS-grad              9             Divorced
# 3       53  234721         11th              7   Married-civ-spouse
# 4       28  338409    Bachelors             13   Married-civ-spouse
# ...    ...     ...          ...            ...                  ...
# 32556   27  257302   Assoc-acdm             12   Married-civ-spouse
# 32557   40  154374      HS-grad              9   Married-civ-spouse
# 32558   58  151910      HS-grad              9              Widowed
# 32559   22  201490      HS-grad              9        Never-married
# 32560   52  287927      HS-grad              9   Married-civ-spouse
#
#                occupation  capital_gain  capital_loss  hours_per_week  \
# 0            Adm-clerical          2174             0              40
# ...

# %%
## removing marital status from the data set (which is not requied)
df1 = df1.drop("marital_status",axis = 1)
df1
# Out:
#        Age  Fnlwgt    Education  education_num          occupation  \
# 0       39   77516    Bachelors             13        Adm-clerical
# 1       50   83311    Bachelors             13     Exec-managerial
# 2       38  215646      HS-grad              9   Handlers-cleaners
# 3       53  234721         11th              7   Handlers-cleaners
# 4       28  338409    Bachelors             13      Prof-specialty
# ...    ...     ...          ...            ...                 ...
# 32556   27  257302   Assoc-acdm             12        Tech-support
# 32557   40  154374      HS-grad              9   Machine-op-inspct
# 32558   58  151910      HS-grad              9        Adm-clerical
# 32559   22  201490      HS-grad              9        Adm-clerical
# 32560   52  287927      HS-grad              9     Exec-managerial
#
#        capital_gain  capital_loss  hours_per_week  native_country  income
# 0              2174             0              40   United-States   <=50K
# ...

# %%
## removing Education from the data set (which is not requied)
df1 = df1.drop("Education",axis = 1)
df1
# Out:
#        Age  Fnlwgt  education_num          occupation  capital_gain  \
# 0       39   77516             13        Adm-clerical          2174
# 1       50   83311             13     Exec-managerial             0
# 2       38  215646              9   Handlers-cleaners             0
# 3       53  234721              7   Handlers-cleaners             0
# 4       28  338409             13      Prof-specialty             0
# ...    ...     ...            ...                 ...           ...
# 32556   27  257302             12        Tech-support             0
# 32557   40  154374              9   Machine-op-inspct             0
# 32558   58  151910              9        Adm-clerical             0
# 32559   22  201490              9        Adm-clerical             0
# 32560   52  287927              9     Exec-managerial         15024
#
#        capital_loss  hours_per_week  native_country  income
# 0                 0              40   United-States   <=50K
# ...

# %%
## removing income from the data set (which is not requied)
df1 = df1.drop("income",axis = 1)
df1
# Out:
#        Age  Fnlwgt  education_num          occupation  capital_gain  \
# 0       39   77516             13        Adm-clerical          2174
# 1       50   83311             13     Exec-managerial             0
# 2       38  215646              9   Handlers-cleaners             0
# 3       53  234721              7   Handlers-cleaners             0
# 4       28  338409             13      Prof-specialty             0
# ...    ...     ...            ...                 ...           ...
# 32556   27  257302             12        Tech-support             0
# 32557   40  154374              9   Machine-op-inspct             0
# 32558   58  151910              9        Adm-clerical             0
# 32559   22  201490              9        Adm-clerical             0
# 32560   52  287927              9     Exec-managerial         15024
#
#        capital_loss  hours_per_week  native_country
# 0                 0              40   United-States
# ...

# %%
## removing native country from the data set (which is not requied)
df1 = df1.drop("native_country",axis = 1)
df1
# Out:
#        Age  Fnlwgt  education_num          occupation  capital_gain  \
# 0       39   77516             13        Adm-clerical          2174
# 1       50   83311             13     Exec-managerial             0
# 2       38  215646              9   Handlers-cleaners             0
# 3       53  234721              7   Handlers-cleaners             0
# 4       28  338409             13      Prof-specialty             0
# ...    ...     ...            ...                 ...           ...
# 32556   27  257302             12        Tech-support             0
# 32557   40  154374              9   Machine-op-inspct             0
# 32558   58  151910              9        Adm-clerical             0
# 32559   22  201490              9        Adm-clerical             0
# 32560   52  287927              9     Exec-managerial         15024
#
#        capital_loss  hours_per_week
# 0                 0              40
# 1                 0              13
# 2                 0              40
# ...

# %%
## removing occupation from the data set (which is not requied)
df1 = df1.drop("occupation",axis = 1)
df1
# Out:
#        Age  Fnlwgt  education_num  capital_gain  capital_loss  hours_per_week
# 0       39   77516             13          2174             0              40
# 1       50   83311             13             0             0              13
# 2       38  215646              9             0             0              40
# 3       53  234721              7             0             0              40
# 4       28  338409             13             0             0              40
# ...    ...     ...            ...           ...           ...             ...
# 32556   27  257302             12             0             0              38
# 32557   40  154374              9             0             0              40
# 32558   58  151910              9             0             0              40
# 32559   22  201490              9             0             0              20
# 32560   52  287927              9         15024             0              40
#
# [32561 rows x 6 columns]

# %%
for i in df1.columns:
    print(i ,'have unquie values =',df1[i].unique(),'\n')
# Out:
# Age have unquie values = [39 50 38 53 28 37 49 52 31 42 30 23 32 40 34 25 43 54 35 59 56 19 20 45
#  22 48 21 24 57 44 41 29 18 47 46 36 79 27 67 33 76 17 55 61 70 64 71 68
#  66 51 58 26 60 90 75 65 77 62 63 80 72 74 69 73 81 78 88 82 83 84 85 86
#  87]
#
# Fnlwgt have unquie values = [ 77516  83311 215646 ...  34066  84661 257302]
#
# education_num have unquie values = [13  9  7 14  5 10 12 11  4 16 15  3  6  2  1  8]
#
# capital_gain have unquie values = [ 2174     0 14084  5178  5013  2407 14344 15024  7688 34095  4064  4386
#   7298  1409  3674  1055  3464  2050  2176   594 20051  6849  4101  1111
#   8614  3411  2597 25236  4650  9386  2463  3103 10605  2964  3325  2580
#   3471  4865 99999  6514  1471  2329  2105  2885 25124 10520  2202  2961
#  27828  6767  2228  1506 13550  2635  5556  4787  3781  3137  3818  3942
#    914   401  2829  2977  4934  2062  2354  5455 15020  1424  3273 22040
#   4416  3908 10566   991  4931  1086  7430  6497   114  7896  2346  3418
# ...

# %%
df1.isin(["?"]).sum()
# Out:
# Age               0
# Fnlwgt            0
# education_num     0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# dtype: int64

# %%
(df1.isin(["?"]).sum()/df1.shape[0])*100
# Out:
# Age               0.0
# Fnlwgt            0.0
# education_num     0.0
# capital_gain      0.0
# capital_loss      0.0
# hours_per_week    0.0
# dtype: float64

# %%
df1.head()
# Out:
#    Age  Fnlwgt  education_num  capital_gain  capital_loss  hours_per_week
# 0   39   77516             13          2174             0              40
# 1   50   83311             13             0             0              13
# 2   38  215646              9             0             0              40
# 3   53  234721              7             0             0              40
# 4   28  338409             13             0             0              40

# %%
# for plotting 
sns.heatmap(df1.corr(),annot = True,cmap = "winter")
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df1.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df1)

# %%
X = df1.iloc[:,1:].values
X
# Out:
# array([[ 77516,     13,   2174,      0,     40],
#        [ 83311,     13,      0,      0,     13],
#        [215646,      9,      0,      0,     40],
#        ...,
#        [151910,      9,      0,      0,     40],
#        [201490,      9,      0,      0,     20],
#        [287927,      9,  15024,      0,     40]], dtype=int64)

# %%
Y = df1.iloc[:,0].values
Y
# Out:
# array([39, 50, 38, ..., 58, 22, 52], dtype=int64)

# %% [markdown]
# # KNN Classifier

# %%
from sklearn.model_selection import train_test_split
Xtrain,Xtest,Ytrain,Ytest = train_test_split(X,Y,test_size=1/3,random_state = 0)

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor(n_neighbors = 10)
knn.fit(Xtrain, Ytrain)
Ypred = knn.predict(Xtest)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(Ytest,Ypred)
# Out:
# 11.055620047908604

# %% [markdown]
# # SVC Classifier

# %%
A = df.iloc[:,[1,3,5,6,7,8,9,13]]
B = df.iloc[:,[0,2,4,10,11,12,14]]
A
# Out:
#                Workclass    Education       marital_status  \
# 0              State-gov    Bachelors        Never-married
# 1       Self-emp-not-inc    Bachelors   Married-civ-spouse
# 2                Private      HS-grad             Divorced
# 3                Private         11th   Married-civ-spouse
# 4                Private    Bachelors   Married-civ-spouse
# ...                  ...          ...                  ...
# 32556            Private   Assoc-acdm   Married-civ-spouse
# 32557            Private      HS-grad   Married-civ-spouse
# 32558            Private      HS-grad              Widowed
# 32559            Private      HS-grad        Never-married
# 32560       Self-emp-inc      HS-grad   Married-civ-spouse
#
#                occupation    relationship    race      sex  native_country
# 0            Adm-clerical   Not-in-family   White     Male   United-States
# 1         Exec-managerial         Husband   White     Male   United-States
# ...

# %%
B
# Out:
#        Age  Fnlwgt  education_num  capital_gain  capital_loss  hours_per_week  \
# 0       39   77516             13          2174             0              40
# 1       50   83311             13             0             0              13
# 2       38  215646              9             0             0              40
# 3       53  234721              7             0             0              40
# 4       28  338409             13             0             0              40
# ...    ...     ...            ...           ...           ...             ...
# 32556   27  257302             12             0             0              38
# 32557   40  154374              9             0             0              40
# 32558   58  151910              9             0             0              40
# 32559   22  201490              9             0             0              20
# 32560   52  287927              9         15024             0              40
#
#        income
# 0       <=50K
# ...

# %%
x = B.drop("income", axis =1)

# %%
y = B["income"]

# %%
x.head()
# Out:
#    Age  Fnlwgt  education_num  capital_gain  capital_loss  hours_per_week
# 0   39   77516             13          2174             0              40
# 1   50   83311             13             0             0              13
# 2   38  215646              9             0             0              40
# 3   53  234721              7             0             0              40
# 4   28  338409             13             0             0              40

# %%
y.head()
# Out:
# 0     <=50K
# 1     <=50K
# 2     <=50K
# 3     <=50K
# 4     <=50K
# Name: income, dtype: object

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC 
xtrain,xtest,ytrain,ytest = train_test_split(x,y)

# %%
svc = SVC()
svc.fit(xtrain,ytrain)
# Out:
# SVC()

# %%
svc.score(xtest,ytest)
# Out:
# 0.7870040535560742

# %%
svc.score(xtrain,ytrain)
# Out:
# 0.7969287469287469

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state=0)
classifier.fit(xtrain,ytrain)
# Out:
# LogisticRegression(random_state=0)

# %%
ypred = classifier.predict(xtest)
ypred
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' <=50K', ' <=50K'],
#       dtype=object)

# %%
ytest
# Out:
# 4475       >50K
# 14248     <=50K
# 30607     <=50K
# 1583       >50K
# 5269       >50K
#           ...
# 23430     <=50K
# 21731     <=50K
# 3381       >50K
# 10252     <=50K
# 21942     <=50K
# Name: income, Length: 8141, dtype: object

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(ytest,ypred)
cm
# Out:
# array([[5921,  191],
#        [1492,  537]], dtype=int64)

# %%
from sklearn import metrics
print('Accuracy:',metrics.accuracy_score(ytest,ypred))
# Out:
# Accuracy: 0.7932686402161897

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=10,criterion='entropy',random_state=0)
clf.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
from sklearn import metrics
print('Accuracy:',metrics.accuracy_score(ytest,ypred))
# Out:
# Accuracy: 0.7932686402161897
